# %% [markdown]
# <a href="https://colab.research.google.com/github/dis-is-pj/Company-Classification-Capstone-Project/blob/main/Prashant_Jha_Company_Classification_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
path = '/content/drive/MyDrive/Cohort Nilgiri/Module 4/Unsupervised Learning Capstone Project/data_company_classification.csv'

# %%
# let's load the data
df = pd.read_csv(path)

# %%
# have a look at the data
df.head()
# Out:
#                   website  ...                                   meta_description
# 0         bipelectric.com  ...  Providing quality, reliable full service resid...
# 1        eliasmedical.com  ...  For the best value in Bakersfield skin care tr...
# 2  koopsoverheaddoors.com  ...  Koops Overhead Doors specializes in the sales,...
# 3         midtowneyes.com  ...  We would like to welcome you to Midtown Eyecar...
# 4     reprosecurity.co.uk  ...  Repro Security provide a range of tailor made ...
#
# [5 rows x 9 columns]

# %%
# size of data
df.shape
# Out:
# (73974, 9)

# %%
# null value analysis
df.isnull().sum()
# Out:
# website                 0
# company_name            0
# homepage_text         669
# h1                  27321
# h2                  20762
# h3                  29315
# nav_link_text       25924
# meta_keywords       50302
# meta_description     7088
# dtype: int64

# %%
df.isnull().sum().plot.bar()

# %%
# making a new column by combining h1,h2,h3

df['headings'] = df['h1'].fillna('') + df['h2'].fillna('') + df['h3'].fillna('')

# %%
# now look at the null values in new columns
df.isnull().sum()
# Out:
# website                 0
# company_name            0
# homepage_text         669
# h1                  27321
# h2                  20762
# h3                  29315
# nav_link_text       25924
# meta_keywords       50302
# meta_description     7088
# headings                0
# new_col             69807
# dtype: int64

# %%
df.head()
# Out:
#                   website  ... new_col
# 0         bipelectric.com  ...     NaN
# 1        eliasmedical.com  ...     NaN
# 2  koopsoverheaddoors.com  ...     NaN
# 3         midtowneyes.com  ...     NaN
# 4     reprosecurity.co.uk  ...     NaN
#
# [5 rows x 11 columns]

# %%
# try combining all columns with huge null values
df['new_col'] = df['h1'] + df['h2'] + df['h3'] + df['nav_link_text'] + df['meta_keywords']

# %%
df.isnull().sum()['new_col']
# Out:
# 69807

# %% [markdown]
# Still there are huge null values
